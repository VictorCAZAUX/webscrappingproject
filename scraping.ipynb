# %%
import requests
page = requests.get("https://photo.capital.fr/les-grandes-villes-francaises-ou-vous-avez-le-plus-de-chance-d-avoir-un-emploi-stable-33978#20-rennes-586638")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n\n\n    <!doctype html>\n    <html lang="fr">\n    <head>\n        <meta charset="UTF-8" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n            <title>Les (grandes) villes fran\xc3\xa7aises o\xc3\xb9 vous avez le plus de chance d\xe2\x80\x99avoir un emploi stable - Capital</title>\n                    <meta name="prismadmin" content=\'{"type":"slideshow","id":"806acb3f-17a9-4436-b79d-58113563484f"}\' />\n                                                <meta name="google-site-verification" content="jesaispas" />\n                        <meta name="robots" content="max-snippet:-1, max-image-preview:standard, max-video-preview:-1" />\n            <link rel="canonical" href="https://photo.capital.fr/les-grandes-villes-francaises-ou-vous-avez-le-plus-de-chance-d-avoir-un-emploi-stable-33978" />\n        \n    \n    <meta name="parsely-title" content="Les (grandes) villes fran\x
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Les (grandes) villes françaises où vous avez le plus de chance d’avoir un emploi stable - Capital
#   </title>
#   <meta content='{"type":"slideshow","id":"806acb3f-17a9-4436-b79d-58113563484f"}' name="prismadmin"/>
#   <meta content="jesaispas" name="google-site-verification"/>
#   <meta content="max-snippet:-1, max-image-preview:standard, max-video-preview:-1" name="robots"/>
#   <link href="https://photo.capital.fr/les-grandes-villes-francaises-ou-vous-avez-le-plus-de-chance-d-avoir-un-emploi-stable-33978" rel="canonical"/>
#   <meta content="Les (grandes) villes françaises où vous avez le plus de chance d’avoir un emploi stable" name="parsely-title"/>
# ...

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html lang="fr">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <title>Les (grandes) villes françaises où vous avez le plus de chance d’avoir un emploi stable - Capital</title>
#  <meta content='{"type":"slideshow","id":"806acb3f-17a9-4436-b79d-58113563484f"}' name="prismadmin"/>
#  <meta content="jesaispas" name="google-site-verification"/>
#  <meta content="max-snippet:-1, max-image-preview:standard, max-video-preview:-1" name="robots"/>
#  <link href="https://photo.capital.fr/les-grandes-villes-francaises-ou-vous-avez-le-plus-de-chance-d-avoir-un-emploi-stable-33978" rel="canonical"/>
#  <meta content="Les (grandes) villes françaises où vous avez le plus de chance d’avoir un emploi stable" name="parsely-title"/>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('h2')
# Out:
# [<h2 class="card-title">
#                      Quelles sont les communes qui concentrent le plus de CDI et de fonctionnaires ? Découvrez-le dans notre diaporama
#                </h2>,
#  <h2 class="card-title">
#                      20. Rennes
#                </h2>,
#  <h2 class="card-title">
#                      19. Angers
#                </h2>,
#  <h2 class="card-title">
#                      18. Grenoble
#                </h2>,
#  <h2 class="card-title">
#                      17. Strasbourg
#                </h2>,
#  <h2 class="card-title">
#                      16. Montpellier
#                </h2>,
#  <h2 class="card-title">
#                      15. Lille
#                </h2>,
#  <h2 class="card-title">
#                      14. Bordeaux
#                </h2>,
#  <h2 class="card-title">
#                      13. Toulouse
#                </h2>,
#  <h2 class="card-title">
#                      12. Nantes
#                </h2>,
#  <h2 class="card-title">
# ...

# %%
len(soup.find_all('h2'))
# Out:
# 24

# %%
soup.find_all(class_="card-title")
# Out:
# [<h2 class="card-title">
#                      Quelles sont les communes qui concentrent le plus de CDI et de fonctionnaires ? Découvrez-le dans notre diaporama
#                </h2>,
#  <h2 class="card-title">
#                      20. Rennes
#                </h2>,
#  <h2 class="card-title">
#                      19. Angers
#                </h2>,
#  <h2 class="card-title">
#                      18. Grenoble
#                </h2>,
#  <h2 class="card-title">
#                      17. Strasbourg
#                </h2>,
#  <h2 class="card-title">
#                      16. Montpellier
#                </h2>,
#  <h2 class="card-title">
#                      15. Lille
#                </h2>,
#  <h2 class="card-title">
#                      14. Bordeaux
#                </h2>,
#  <h2 class="card-title">
#                      13. Toulouse
#                </h2>,
#  <h2 class="card-title">
#                      12. Nantes
#                </h2>,
#  <h2 class="card-title">
# ...

# %%
soup.find_all('h2')[1].get_text()
# Out:
# '\n                    20. Rennes \n              '

# %%
tab = []
for i in soup.find_all('h2'):
    tab.append(i.get_text())

# %%
tab
# Out:
# ['\n                    Quelles sont les communes qui concentrent le plus de CDI et de fonctionnaires ? Découvrez-le dans notre diaporama\n              ',
#  '\n                    20. Rennes \n              ',
#  '\n                    19. Angers\n              ',
#  '\n                    18. Grenoble \n              ',
#  '\n                    17. Strasbourg\n              ',
#  '\n                    16. Montpellier\n              ',
#  '\n                    15. Lille\n              ',
#  '\n                    14. Bordeaux\n              ',
#  '\n                    13. Toulouse\n              ',
#  '\n                    12. Nantes\n              ',
#  '\n                    11. Saint-Étienne\n              ',
#  '\n                    10. Reims\n              ',
#  '\n                    9. Dijon\n              ',
#  '\n                    8. Nîmes\n              ',
#  '\n                    7. Lyon\n              ',
#  '\n                    6. Le Havre\n              ',
# ...

# %%
soup.find_all('h2', class_='')
# Out:
# []

# %%
a = tab[2]
a
# Out:
# '\n                    19. Angers\n              '

# %%
a[21:]
# Out:
# '19. Angers\n              '

# %%
tab2 = []
for i in tab:
    a = i[21:]
    tab2.append(a)

# %%
tab2.pop(20)
# Out:
# ''

# %%
a = tab2[4]
print(a[:-15])
# Out:
# 16. Montpellier

# %%
tab3 = []
for i in tab2:
    tab3.append(i[:-15])

# %%
tab3
# Out:
# ['20. Rennes ',
#  '19. Angers',
#  '18. Grenoble ',
#  '17. Strasbourg',
#  '16. Montpellier',
#  '15. Lille',
#  '14. Bordeaux',
#  '13. Toulouse',
#  '12. Nantes',
#  '11. Saint-Étienne',
#  '10. Reims',
#  '9. Dijon',
#  '8. Nîmes',
#  '7. Lyon',
#  '6. Le Havre',
#  '5. Toulon',
#  '4. Villeurbanne',
#  '3. Paris',
#  '2. Nice',
#  '1. Marseille']

# %%
tab4 = []
tab5 = []
for i in tab3:
    a = i.split(".")
    tab4.append(a[0])
    tab5.append(a[1])

# %%
tab5
# Out:
# [' Rennes ',
#  ' Angers',
#  ' Grenoble ',
#  ' Strasbourg',
#  ' Montpellier',
#  ' Lille',
#  ' Bordeaux',
#  ' Toulouse',
#  ' Nantes',
#  ' Saint-Étienne',
#  ' Reims',
#  ' Dijon',
#  ' Nîmes',
#  ' Lyon',
#  ' Le Havre',
#  ' Toulon',
#  ' Villeurbanne',
#  ' Paris',
#  ' Nice',
#  ' Marseille']

# %%
k = []
for i in tab5:
    j = i.replace(' ','')
    k.append(j)

# %%
ziplisst = zip(tab4,k)

# %%
ziplisst

# %%
df = pd.DataFrame(ziplisst)

# %%
del df[0]

# %%
df = df.rename(columns={1: 'Villes'})

# %%
df
# Out:
#            Villes
# 0          Rennes
# 1          Angers
# 2        Grenoble
# 3      Strasbourg
# 4     Montpellier
# 5           Lille
# 6        Bordeaux
# 7        Toulouse
# 8          Nantes
# 9   Saint-Étienne
# 10          Reims
# 11          Dijon
# 12          Nîmes
# 13           Lyon
# 14        LeHavre
# 15         Toulon
# 16   Villeurbanne
# 17          Paris
# 18           Nice
# 19      Marseille

# %%
df.to_csv("villesascrap.csv",index=False)
